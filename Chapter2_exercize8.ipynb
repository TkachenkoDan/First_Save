# %% [markdown]
# <a href="https://colab.research.google.com/github/TkachenkoDan/First_Save/blob/main/Chapter2_exercize8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# а) Успешно получить данные с https://www.statlearning.com/resources-python

# %%
import pandas as pd
college = pd.read_csv('College.csv')
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# b) Название колледжа - это индекс (2 способа)

# %%
college2 = pd.read_csv('College.csv', index_col=0)
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
college3 = college3.set_index('College')
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# c) Обобщенная статистика

# %%
college = college3
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# d) Матрица по 3 параметрам ('Top10perc', 'Apps', 'Enroll')

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']]);

# %% [markdown]
# e) Ящик с усами для Outstate и Private

# %%
from matplotlib.pyplot import subplots
fig, ax = subplots(figsize=(8, 8))
college.boxplot('Outstate', by='Private', ax=ax);

# %% [markdown]
# f)Elite - новая переменная, делящую Top10per на 2 группы - 10 % лучших учеников в школе в верхней половине или нет

# %%
college['Elite'] = pd.cut(college['Top10perc'], bins=[0, 50, 100], labels=['No', 'Yes'])
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
fig, ax = subplots(figsize=(8, 8))
college.boxplot('Outstate', by='Elite', ax=ax);

# %% [markdown]
# g) Вывести гистограммы для качественных переменных
#
# Надо вывести 4 качественных переменных, но их всего 2(Private и Elite). К тому же Elite хранится каким-то странным образом (не через array), поэтому если построить обысную гистограмму, то выведется ошибка. Когда-нибудь надо разобраться...

# %%
import numpy as np
all_colums = college.columns
for x in all_colums:
  print(x, len(np.unique(college[x])))
# Out:
# Private 2
# Apps 711
# Accept 693
# Enroll 581
# Top10perc 82
# Top25perc 89
# F.Undergrad 714
# P.Undergrad 566
# Outstate 640
# Room.Board 553
# Books 122
# Personal 294
# PhD 78
# Terminal 65
# S.F.Ratio 173
# perc.alumni 61
# Expend 744
# Grad.Rate 81
# Elite 2

# %%
college['Private'].replace({'Yes': 1, 'No' :0}, inplace=True)
college
# Out:
# /tmp/ipython-input-40-837304942.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   college['Private'].replace({'Yes': 1, 'No' :0}, inplace=True)
# /tmp/ipython-input-40-837304942.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
college['Elite'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No' < 'Yes']

# %%
fig, axes = subplots(nrows=2,
                     ncols=2,
                     figsize=(15, 15))
college.hist('Apps', ax=axes[0][0]);
college.hist('Private', ax=axes[0][1]);
college.hist('Accept', ax=axes[1][0]);

# %% [markdown]
# h) Продолжите исследовать данные и составьте вывод
#
# Непонятно, что ещё искать. Как видно из боксплотов, в частных и элитных колледжах учиться дороже, чем в государственных и неэлитных (вау!)
